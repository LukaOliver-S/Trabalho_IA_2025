# %%
import numpy as np

try:
    data = np.load(r"C:\Users\User\Documents\IA_PROJECT\Archives\files_webot\IA_20252\controllers\lidar_dataset\dataset_lidar_pose\sample_00010.npz")
    print("Chaves:", data.files)
    print("Lidar shape:", data["lidar"].shape)
    print("Pose shape:", data["pose"].shape)
    print("Primeiros 10 do lidar:", data["lidar"])
    print("Pose:", data["pose"])
except Exception as e:
    print("Erro ao carregar ou imprimir:", e)
# Out:
# Chaves: ['lidar', 'pose']
# Lidar shape: (360,)
# Pose shape: (3,)
# Primeiros 10 do lidar: [0.7340335  0.73440504 0.7349944  0.7358021  0.7368134  0.7380725
#  0.73995566 0.7416991  0.7436645  0.7459285  0.74838233 0.75107116
#  0.75400054 0.7571762  0.76067674 0.7643849  0.7683571  0.7726006
#  0.7771227  0.7819318  0.7870363  0.7924456  0.79816926 0.8042183
#  0.8106035  0.81733686 0.8244316  0.83190143 0.8397611  0.8480265
#  0.8567145  0.8658441  0.8754341  0.88550633 0.8960832  0.90732956
#  0.9189974  0.9312507  0.9441201  0.9576395  0.9718458  0.9867781
#  1.0024796  1.0189974  1.0363821  1.0546895  1.0739805  1.0943213
#  1.1157845  1.1384494  1.1624043  1.1877451  1.2145777  1.2430199
#  1.2732012  1.3052652  1.3393706  1.3762354  1.4151604  1.4567617
#  1.5012925  1.5490403  1.6011385  1.6567258  1.7530401  1.821407
#  1.8958588  1.9771982  2.0663686  2.1644876  2.2728853  2.3978522
#  2.533962   2.6869047  2.859794   3.05652    3.2933419  3.563427
# ...
